# %% [markdown]
# <a href="https://colab.research.google.com/github/dhan-t/CCMACLRL_EXAM_COM222-ML-/blob/main/Midterms_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/train.csv?raw=true'
df = pd.read_csv(dataset_url)
test_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/test.csv?raw=true'
dt=pd.read_csv(test_url)
sample_submission_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/a46a4e2a001dedaefc9b431d480b508ce86c2d96/datasets/sample_submission.csv?raw=true'
sf=pd.read_csv(sample_submission_url)

# %%
df.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %%
df.isnull().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
df.describe()
# Out:
#                   id     model_year         milage         price
# count  162610.000000  162610.000000  162610.000000  1.626100e+05
# mean    94197.039137    2015.158822   71105.487086  4.081699e+04
# std     54467.770815       5.699531   50157.874111  7.653857e+04
# min         0.000000    1974.000000     100.000000  2.000000e+03
# 25%     47026.250000    2012.000000   29000.000000  1.570000e+04
# 50%     94139.000000    2016.000000   64300.000000  2.850000e+04
# 75%    141421.750000    2019.000000  101000.000000  4.699900e+04
# max    188532.000000    2024.000000  405000.000000  2.954083e+06

# %%
df.sample(20)
# Out:
#             id          brand                                         model  \
# 125846  125846       Cadillac                                    CTS Luxury
# 14451    14451           Land  Rover Range Rover Sport Supercharged Dynamic
# 78469    78469          Aston                       Martin DBS Superleggera
# 155104  155104           Ford                                      F-150 XL
# 74545    74545            BMW                                  X1 sDrive28i
# 55523    55523         Toyota                   Highlander Limited Platinum
# 11804    11804          Lexus                                  RX 450h Base
# 115883  115883            GMC                                    Acadia SLE
# 98058    98058         Jaguar                                      XK8 Base
# 156921  156921  Mercedes-Benz                                  E-Class E500
# 117840  117840         Toyota                           Camry Solara SLE V6
# 110015  110015         Toyota                                    Tundra SR5
# 86869    86869      Chevrolet                       Corvette Stingray w/3LT
# 3842      3842            BMW                                       M4 Base
# 54102    54102            BMW                                  750 i xDrive
# 64921    64921           Audi                             SQ5 3.0T Prestige
# 4932      4932           Audi                          S4 3.0T Premium Plus
# 82180    82180  Mercedes-Benz                              C-Class C 63 AMG
# 174091  174091            BMW                                        M240 i
# 114022  114022           Land                 Rover Range Rover Evoque Pure
#
#         model_year  milage      fuel_type  \
# 125846        2008   96600       Gasoline
# 14451         2018   57000       Gasoline
# 78469         2019   22770       Gasoline
# 155104        2017   14700  E85 Flex Fuel
# 74545         2022   12800       Gasoline
# 55523         2016  135140       Gasoline
# 11804         2021   30450         Hybrid
# 115883        2019   58500       Gasoline
# 98058         2000   40000       Gasoline
# 156921        2008   74000       Gasoline
# 117840        2004  131000       Gasoline
# 110015        2019   65441       Gasoline
# 86869         2022    1800       Gasoline
# 3842          2018   19600       Gasoline
# 54102         1999  123500       Gasoline
# 64921         2016  119000       Gasoline
# 4932          2012   76500       Gasoline
# 82180         2013   24500       Gasoline
# 174091        2021   44000       Gasoline
# 114022        2017   84000       Gasoline
#
#                                                    engine  \
# 125846      270.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 14451        518.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 78469                    5.2L V12 48V GDI DOHC Twin Turbo
# 155104  395.0HP 5.0L 8 Cylinder Engine Flex Fuel Capab...
# 74545        228.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 55523       270.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 11804   308.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 115883      310.0HP 3.6L V6 Cylinder Engine Gasoline Fuel
# 98058        290.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 156921       302.0HP 4.6L 8 Cylinder Engine Gasoline Fuel
# 117840      210.0HP 3.3L V6 Cylinder Engine Gasoline Fuel
# 110015       381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 86869        490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 3842    425.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 54102        300.0HP 5.4L 8 Cylinder Engine Gasoline Fuel
# 64921       354.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4932        333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 82180        451.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 174091  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 114022       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                           transmission ext_col int_col  \
# 125846                     5-Speed A/T  Silver       –
# 14451                      8-Speed A/T   Black   Black
# 78469                8-Speed Automatic   Black   Black
# 155104                     6-Speed A/T  Silver   Black
# 74545   Transmission w/Dual Shift Mode   Black    Blue
# 55523                              A/T   White   Beige
# 11804                 CVT Transmission  Silver   Black
# 115883                     9-Speed A/T    Gray   Black
# 98058                      5-Speed A/T   Green   Beige
# 156921                             A/T  Silver   Black
# 117840                             A/T     Red   Black
# 110015                     6-Speed A/T   Black    Gray
# 86869                      8-Speed A/T  Yellow   Black
# 3842                       7-Speed A/T    Gray  Silver
# 54102                              A/T   Black   Black
# 64921                      8-Speed A/T   Black   Beige
# 4932                               A/T   Black   Black
# 82180                      7-Speed A/T   Black   Black
# 174091                     6-Speed M/T    Blue    Gray
# 114022                     9-Speed A/T    Gray   Black
#
#                                       accident clean_title  price
# 125846                           None reported         Yes  11500
# 14451                            None reported         Yes  45000
# 78469                            None reported         Yes  72567
# 155104  At least 1 accident or damage reported         Yes  29000
# 74545                            None reported         Yes  35000
# 55523                            None reported         Yes  24000
# 11804                            None reported         Yes  49995
# 115883                           None reported         Yes  35000
# 98058                            None reported         Yes  30000
# 156921                           None reported         Yes  19500
# 117840                           None reported         Yes   7350
# 110015  At least 1 accident or damage reported         Yes  42000
# 86869                            None reported         Yes  60000
# 3842                             None reported         Yes  65900
# 54102   At least 1 accident or damage reported         Yes  12500
# 64921   At least 1 accident or damage reported         Yes  23500
# 4932                             None reported         Yes  20000
# 82180                            None reported         Yes  35000
# 174091                           None reported         Yes  37000
# 114022                           None reported         Yes  24000

# %%
from datetime import datetime

current_year = datetime.now().year
df['car_age'] = current_year - df['model_year'].astype(str).str.split('-', expand=True).astype(int)

# %%
df.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price  car_age
# 0                           None reported         Yes   4200       17
# 1  At least 1 accident or damage reported         Yes   4999       22
# 2                           None reported         Yes  13900       22
# 3                           None reported         Yes  45000        7
# 4                           None reported         Yes  97500        3

# %%
def extract_luxury(brand):
    luxury_yes = [
    'Lexus',
    'Audi',
    'BMW',
    'Mercedes-Benz',
    'Jaguar',
    'Porsche',
    'Rolls-Royce',
    'Lamborghini',
    'Maserati',
    'Ferrari',
    'McLaren',
    'Bentley',
    'Tesla',
    'Cadillac',
    'McLaren',
    'Volvo',
    'Land Rover',
    'Genesis',

]
    Yes = "Yes"
    No = "No"
    for is_luxury in luxury_yes:
        if is_luxury.lower() in brand.lower():
            return Yes
    return No

# Apply the function to create a new column
df['is_luxury'] = df['brand'].apply(extract_luxury)

# %%
df['transmission'] = df['transmission'].replace({
    'A/T': 'A/T',
    'Transmission w/Dual Shift Mode': 'DCT',
    '7-Speed A/T': 'A/T',
    '8-Speed A/T': 'A/T',
    '10-Speed Automatic': 'A/T',
    '6-Speed A/T': 'A/T',
    '10-Speed A/T': 'A/T',
    '9-Speed A/T': 'A/T',
    '9-Speed Automatic': 'A/T',
    '5-Speed A/T': 'A/T',
    '8-Speed Automatic': 'A/T',
    'CVT Transmission': 'CVT',
    '5-Speed M/T': 'M/T',
    'M/T': 'M/T',
    '6-Speed M/T': 'M/T',
    '6-Speed Automatic': 'A/T',
    '4-Speed Automatic': 'A/T',
    '7-Speed M/T': 'M/T',
    'Automatic': 'A/T',
    '4-Speed A/T': 'A/T',
    '2-Speed A/T': 'A/T',
    '6-Speed Manual': 'M/T',
    'Transmission Overdrive Switch': 'A/T',
    '8-Speed Automatic with Auto-Shift': 'A/T',
    '7-Speed Automatic with Auto-Shift': 'A/T',
    'Automatic CVT': 'CVT',
    '1-Speed A/T': 'A/T',
    '6-Speed Electronically Controlled Automatic with O': 'A/T',
    'F': None,
    '8-Speed Manual': 'M/T',
    '6-Speed Automatic with Auto-Shift': 'A/T',
    '7-Speed Automatic': 'A/T',
    '7-Speed Manual': 'M/T',
    '7-Speed': None,
    'Single-Speed Fixed Gear': None,
    '8-SPEED AT': 'A/T',
    '10-Speed Automatic with Overdrive': 'A/T',
    '2-Speed Automatic': 'A/T',
    'CVT-F': 'CVT',
    '5-Speed Automatic': 'A/T',
    '–': None,
    '7-Speed DCT Automatic': 'DCT',
    'Manual': 'M/T',
    '2': None,
    '1-Speed Automatic': 'A/T',
    '6-Speed': None,
    'SCHEDULED FOR OR IN PRODUCTION': None,
    'Variable': None,
    '9-Speed Automatic with Auto-Shift': 'A/T',
    '6 Speed Mt': 'M/T',
    '6 Speed At/Mt': 'DCT',
    '8-SPEED A/T': 'A/T'
})

# %%
df['accident'] = df['accident'].replace({
    'None reported': 'No',
    'At least 1 accident or damage reported': 'Yes',
})

# %%
df
# Out:
#             id          brand                     model  model_year  milage  \
# 0            0           MINI             Cooper S Base        2007  213000
# 1            1        Lincoln                     LS V8        2002  143250
# 2            2      Chevrolet         Silverado 2500 LT        2002  136731
# 3            3        Genesis          G90 5.0 Ultimate        2017   19500
# 4            4  Mercedes-Benz               Metris Base        2021    7388
# ...        ...            ...                       ...         ...     ...
# 188527  188527      Chevrolet                Camaro Z28        1999  110000
# 188528  188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188532  188532        Porsche                Macan Base        2016   59500
#
#             fuel_type                                             engine  \
# 0            Gasoline       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1            Gasoline       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2       E85 Flex Fuel  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3            Gasoline       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4            Gasoline       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...               ...                                                ...
# 188527       Gasoline       310.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 188528       Gasoline       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188529       Gasoline      385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188530       Gasoline       469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188532       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#        transmission ext_col int_col accident clean_title  price  car_age  \
# 0               A/T  Yellow    Gray       No         Yes   4200       17
# 1               A/T  Silver   Beige      Yes         Yes   4999       22
# 2               A/T    Blue    Gray       No         Yes  13900       22
# 3               DCT   Black   Black       No         Yes  45000        7
# 4               A/T   Black   Beige       No         Yes  97500        3
# ...             ...     ...     ...      ...         ...    ...      ...
# 188527          A/T   White    Gray       No         Yes  14500       25
# 188528          DCT   White   Beige       No         Yes  27500        7
# 188529          A/T   White   Black      Yes         Yes  30000        6
# 188530          A/T   White   Black       No         Yes  86900        3
# 188532          DCT   White   Black       No         Yes  28995        8
#
#        is_luxury
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes
# ...          ...
# 188527        No
# 188528       Yes
# 188529       Yes
# 188530       Yes
# 188532       Yes
#
# [162610 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# id               0
# brand            0
# model            0
# model_year       0
# milage           0
# fuel_type        0
# engine           0
# transmission    92
# ext_col          0
# int_col          0
# accident         0
# clean_title      0
# price            0
# car_age          0
# is_luxury        0
# dtype: int64

# %%
label_encoder = LabelEncoder()
df['brand'] = label_encoder.fit_transform(df['brand'])

# %%
drop_col=['id','ext_col','int_col', 'fuel_type', 'engine', 'model', 'clean_title']
df.drop(drop_col,inplace=True,axis=1)
object_columns = df.select_dtypes(include=['object']).columns
df[object_columns]
# Out:
#        transmission accident is_luxury
# 0               A/T       No        No
# 1               A/T      Yes        No
# 2               A/T       No        No
# 3               DCT       No       Yes
# 4               A/T       No       Yes
# ...             ...      ...       ...
# 188527          A/T       No        No
# 188528          DCT       No       Yes
# 188529          A/T      Yes       Yes
# 188530          A/T       No       Yes
# 188532          DCT       No       Yes
#
# [162610 rows x 3 columns]

# %%
for column in object_columns:
    unique_values = df[column].unique()
    print(f"Unique values in '{column}':")
    print(unique_values)
    print()
# Out:
# Unique values in 'transmission':
# ['A/T' 'DCT' 'CVT' 'M/T' None]
#
# Unique values in 'accident':
# ['No' 'Yes']
#
# Unique values in 'is_luxury':
# ['No' 'Yes']

# %%
df = pd.get_dummies(df, columns=object_columns)

# %%
df
# Out:
#         brand  model_year  milage  price  car_age  transmission_A/T  \
# 0          31        2007  213000   4200       17              True
# 1          28        2002  143250   4999       22              True
# 2           9        2002  136731  13900       22              True
# 3          16        2017   19500  45000        7             False
# 4          36        2021    7388  97500        3              True
# ...       ...         ...     ...    ...      ...               ...
# 188527      9        1999  110000  14500       25              True
# 188528      8        2017   49000  27500        7             False
# 188529     36        2018   28600  30000        6              True
# 188530     36        2021   13650  86900        3              True
# 188532     43        2016   59500  28995        8             False
#
#         transmission_CVT  transmission_DCT  transmission_M/T  accident_No  \
# 0                  False             False             False         True
# 1                  False             False             False        False
# 2                  False             False             False         True
# 3                  False              True             False         True
# 4                  False             False             False         True
# ...                  ...               ...               ...          ...
# 188527             False             False             False         True
# 188528             False              True             False         True
# 188529             False             False             False        False
# 188530             False             False             False         True
# 188532             False              True             False         True
#
#         accident_Yes  is_luxury_No  is_luxury_Yes
# 0              False          True          False
# 1               True          True          False
# 2              False          True          False
# 3              False         False           True
# 4              False         False           True
# ...              ...           ...            ...
# 188527         False          True          False
# 188528         False         False           True
# 188529          True         False           True
# 188530         False         False           True
# 188532         False         False           True
#
# [162610 rows x 13 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
non_boolean_numerical_features = ["model_year",'milage','price','car_age']
scaler = MinMaxScaler()
df[non_boolean_numerical_features] = scaler.fit_transform(df[non_boolean_numerical_features])

# %%
df
# Out:
#         brand  model_year    milage     price  car_age  transmission_A/T  \
# 0          31        0.66  0.525809  0.000745     0.34              True
# 1          28        0.56  0.353544  0.001016     0.44              True
# 2           9        0.56  0.337444  0.004031     0.44              True
# 3          16        0.86  0.047913  0.014566     0.14             False
# 4          36        0.94  0.018000  0.032350     0.06              True
# ...       ...         ...       ...       ...      ...               ...
# 188527      9        0.50  0.271425  0.004234     0.50              True
# 188528      8        0.86  0.120771  0.008638     0.14             False
# 188529     36        0.88  0.070388  0.009485     0.12              True
# 188530     36        0.94  0.033465  0.028759     0.06              True
# 188532     43        0.84  0.146703  0.009144     0.16             False
#
#         transmission_CVT  transmission_DCT  transmission_M/T  accident_No  \
# 0                  False             False             False         True
# 1                  False             False             False        False
# 2                  False             False             False         True
# 3                  False              True             False         True
# 4                  False             False             False         True
# ...                  ...               ...               ...          ...
# 188527             False             False             False         True
# 188528             False              True             False         True
# 188529             False             False             False        False
# 188530             False             False             False         True
# 188532             False              True             False         True
#
#         accident_Yes  is_luxury_No  is_luxury_Yes
# 0              False          True          False
# 1               True          True          False
# 2              False          True          False
# 3              False         False           True
# 4              False         False           True
# ...              ...           ...            ...
# 188527         False          True          False
# 188528         False         False           True
# 188529          True         False           True
# 188530         False         False           True
# 188532         False         False           True
#
# [162610 rows x 13 columns]

# %%
df
# Out:
#         brand  model_year    milage     price  car_age  transmission_A/T  \
# 0          31        0.66  0.525809  0.000745     0.34              True
# 1          28        0.56  0.353544  0.001016     0.44              True
# 2           9        0.56  0.337444  0.004031     0.44              True
# 3          16        0.86  0.047913  0.014566     0.14             False
# 4          36        0.94  0.018000  0.032350     0.06              True
# ...       ...         ...       ...       ...      ...               ...
# 188527      9        0.50  0.271425  0.004234     0.50              True
# 188528      8        0.86  0.120771  0.008638     0.14             False
# 188529     36        0.88  0.070388  0.009485     0.12              True
# 188530     36        0.94  0.033465  0.028759     0.06              True
# 188532     43        0.84  0.146703  0.009144     0.16             False
#
#         transmission_CVT  transmission_DCT  transmission_M/T  accident_No  \
# 0                  False             False             False         True
# 1                  False             False             False        False
# 2                  False             False             False         True
# 3                  False              True             False         True
# 4                  False             False             False         True
# ...                  ...               ...               ...          ...
# 188527             False             False             False         True
# 188528             False              True             False         True
# 188529             False             False             False        False
# 188530             False             False             False         True
# 188532             False              True             False         True
#
#         accident_Yes  is_luxury_No  is_luxury_Yes
# 0              False          True          False
# 1               True          True          False
# 2              False          True          False
# 3              False         False           True
# 4              False         False           True
# ...              ...           ...            ...
# 188527         False          True          False
# 188528         False         False           True
# 188529          True         False           True
# 188530         False         False           True
# 188532         False         False           True
#
# [162610 rows x 13 columns]

# %%
# x = df.drop(['brand_Acura', 'brand_Alfa',        'brand_Aston', 'brand_Audi', 'brand_BMW', 'brand_Bentley',        'brand_Bugatti', 'brand_Buick', 'brand_Cadillac', 'brand_Chevrolet',        'brand_Chrysler', 'brand_Dodge', 'brand_FIAT', 'brand_Ferrari',        'brand_Ford', 'brand_GMC', 'brand_Genesis', 'brand_Honda',        'brand_Hummer', 'brand_Hyundai', 'brand_INFINITI', 'brand_Jaguar',        'brand_Jeep', 'brand_Karma', 'brand_Kia', 'brand_Lamborghini',        'brand_Land', 'brand_Lexus', 'brand_Lincoln', 'brand_Lotus',        'brand_Lucid', 'brand_MINI', 'brand_Maserati', 'brand_Maybach',        'brand_Mazda', 'brand_McLaren', 'brand_Mercedes-Benz', 'brand_Mercury',        'brand_Mitsubishi', 'brand_Nissan', 'brand_Plymouth', 'brand_Polestar',        'brand_Pontiac', 'brand_Porsche', 'brand_RAM', 'brand_Rivian',        'brand_Rolls-Royce', 'brand_Saab', 'brand_Saturn', 'brand_Scion',        'brand_Subaru', 'brand_Suzuki', 'brand_Tesla', 'brand_Toyota', 'brand_Volkswagen', 'brand_Volvo', 'brand_smart'],axis=1)
# x

# %%
x = df.drop(['price'],axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = linear_reg.predict(X_train)
y_pred_test = linear_reg.predict(X_test)

# %%
train_mse = mean_squared_error(y_train, y_pred_train)
test_mse = mean_squared_error(y_test, y_pred_test)
train_r2 = r2_score(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)

print(f"Training MSE: {train_mse}")
print(f"Testing MSE: {test_mse}")
print(f"Training R2 Score: {train_r2}")
print(f"Testing R2 Score: {test_r2}")
# Out:
# Training MSE: 0.0005852110441183176
# Testing MSE: 0.0007251596504868553
# Training R2 Score: 0.09055022740662444
# Testing R2 Score: 0.07863572228512661

# %%
model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 0.026928788507596387

# %%
dt['car_age'] = current_year - dt['model_year'].astype(str).str.split('-', expand=True).astype(int)
dt['transmission_A/T'] = df['transmission_A/T'].astype(int)
dt['transmission_CVT'] = df['transmission_CVT'].astype(int)
dt['transmission_DCT'] = df['transmission_DCT'].astype(int)
dt['transmission_M/T'] = df['transmission_M/T'].astype(int)
dt['accident_No'] = df['accident_No'].astype(int)
dt['accident_Yes'] = df['accident_Yes'].astype(int)
dt['is_luxury_No'] = df['is_luxury_No'].astype(int)
dt['is_luxury_Yes'] = df['is_luxury_Yes'].astype(int)


dt.drop(columns=['accident','clean_title','engine', 'ext_col', 'fuel_type', 'id', 'int_col', 'model', 'transmission'], axis=1, inplace=True)

# %%
label_encoder = LabelEncoder()
dt['brand'] = label_encoder.fit_transform(dt['brand'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162610 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   brand             162610 non-null  int64
#  1   model_year        162610 non-null  float64
#  2   milage            162610 non-null  float64
#  3   price             162610 non-null  float64
#  4   car_age           162610 non-null  float64
#  5   transmission_A/T  162610 non-null  bool
#  6   transmission_CVT  162610 non-null  bool
#  7   transmission_DCT  162610 non-null  bool
#  8   transmission_M/T  162610 non-null  bool
#  9   accident_No       162610 non-null  bool
#  10  accident_Yes      162610 non-null  bool
#  11  is_luxury_No      162610 non-null  bool
#  12  is_luxury_Yes     162610 non-null  bool
# dtypes: bool(8), float64(4), int64(1)
# memory usage: 12.7 MB

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   brand             125690 non-null  int64
#  1   model_year        125690 non-null  int64
#  2   milage            125690 non-null  int64
#  3   car_age           125690 non-null  int64
#  4   transmission_A/T  108458 non-null  float64
#  5   transmission_CVT  108458 non-null  float64
#  6   transmission_DCT  108458 non-null  float64
#  7   transmission_M/T  108458 non-null  float64
#  8   accident_No       108458 non-null  float64
#  9   accident_Yes      108458 non-null  float64
#  10  is_luxury_No      108458 non-null  float64
#  11  is_luxury_Yes     108458 non-null  float64
# dtypes: float64(8), int64(4)
# memory usage: 11.5 MB

# %%
dt.fillna(0, inplace=True)

# %%
id = sf.pop('id')
y_pred = model.predict(dt)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'class': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission_file.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv
